# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             11776
# 1    1027      Ethereum    ETH      ethereum              9423
# 2     825   Tether USDt   USDT        tether            100423
# 3    1839           BNB    BNB           bnb              2259
# 4    5426        Solana    SOL        solana               767
# 5    3408          USDC   USDC      usd-coin             22491
# 6      52           XRP    XRP           xrp              1404
# 7      74      Dogecoin   DOGE      dogecoin              1080
# 8    1958          TRON    TRX          tron              1050
# 9   11419       Toncoin    TON       toncoin               578
# 10   2010       Cardano    ADA       cardano              1267
# 11   5805     Avalanche   AVAX     avalanche               787
# 12   5994     Shiba Inu   SHIB     shiba-inu               884
# 13   1831  Bitcoin Cash    BCH  bitcoin-cash               934
# 14   1975     Chainlink   LINK     chainlink              1855
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-09-13T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2017-10-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2020-08-01T00:00:00.000Z
# 13  2017-07-23T00:00:00.000Z
# 14  2017-09-20T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10  [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 13  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 14  [platform, defi, oracles, smart-contracts, sub...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.976847e+07  1.976847e+07            False       NaN         1
# 1         1.203862e+08  1.203862e+08             True       NaN         2
# 2         1.199722e+11  1.213629e+11             True       NaN         3
# 3         1.459317e+08  1.459317e+08            False       NaN         4
# 4         4.698603e+08  5.867202e+08             True       NaN         5
# 5         3.477012e+10  3.477012e+10            False       NaN         6
# 6         5.664506e+10  9.998714e+10            False       NaN         7
# 7         1.463923e+11  1.463923e+11             True       NaN         8
# 8         8.653253e+10  8.653261e+10             True       NaN         9
# 9         2.539167e+09  5.113294e+09             True       NaN        10
# 10        3.496719e+10  4.499514e+10            False       NaN        11
# 11        4.066169e+08  4.466200e+08            False       NaN        12
# 12        5.892671e+14  5.895183e+14            False       NaN        13
# 13        1.977506e+07  1.977506e+07            False       NaN        14
# 14        6.268500e+08  1.000000e+09            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                       7.165966e+10              1.142896e+10      None
# 9                       3.414167e+09              1.785211e+10      None
# 10                               NaN                       NaN      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2024-10-16T16:34:00.000Z     67556.553080          4.463649e+10
# 1   2024-10-16T16:34:00.000Z      2597.762419          1.903363e+10
# 2   2024-10-16T16:34:00.000Z         0.999937          7.152950e+10
# 3   2024-10-16T16:34:00.000Z       592.774957          1.886436e+09
# 4   2024-10-16T16:34:00.000Z       154.711699          2.688547e+09
# 5   2024-10-16T16:34:00.000Z         1.000149          7.419407e+09
# 6   2024-10-16T16:34:00.000Z         0.548510          1.076679e+09
# 7   2024-10-16T16:34:00.000Z         0.126063          2.155779e+09
# 8   2024-10-16T16:34:00.000Z         0.159489          3.294895e+08
# 9   2024-10-16T16:34:00.000Z         5.228834          1.873548e+08
# 10  2024-10-16T16:34:00.000Z         0.352448          3.087643e+08
# 11  2024-10-16T16:34:00.000Z        27.413076          4.136818e+08
# 12  2024-10-16T16:34:00.000Z         0.000018          5.547174e+08
# 13  2024-10-16T16:34:00.000Z       362.929633          4.596896e+08
# 14  2024-10-16T16:34:00.000Z        11.129793          2.503054e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -1.1387                    -0.559218
# 1                       -9.5155                    -0.629736
# 2                      -10.3489                     0.007723
# 3                       -5.3968                    -0.642755
# 4                      -15.7837                    -0.637631
# 5                       -7.8424                     0.017570
# 6                      -15.8573                    -0.150950
# 7                       72.2647                     0.069649
# 8                      -16.2813                    -0.084347
# 9                      -25.5293                    -0.667894
# 10                     -18.1149                    -0.940726
# 11                     -13.5264                    -1.035404
# 12                      -5.2767                    -0.943350
# 13                     -26.7011                    -0.817104
# 14                     -30.6788                    -0.630438
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       1.165507                     9.501579
# 1                      -0.229875                     6.801409
# 2                       0.022717                     0.058111
# 3                      -0.020892                     2.618566
# 4                      -0.075499                     9.752871
# 5                       0.025367                     0.011747
# 6                       0.835361                     3.310887
# 7                      10.361534                    14.956308
# 8                       0.657392                    -1.025527
# 9                      -0.278225                     1.763032
# 10                     -2.006225                     4.000215
# 11                     -3.495254                     6.062202
# 12                      1.891341                     8.212614
# 13                      2.222226                    12.187706
# 14                     -1.581811                     5.184098
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      16.882880                     13.539325
# 1                      13.549594                     -0.509455
# 2                      -0.004060                     -0.034393
# 3                      10.996849                     10.649064
# 4                      17.862954                      9.905513
# 5                       0.014570                      0.019523
# 6                      -4.430338                     -3.505747
# 7                      26.674966                     22.473891
# 8                       7.532992                     17.600199
# 9                      -3.604204                    -19.200233
# 10                      6.549012                      4.692697
# 11                     17.084077                     33.254879
# 12                     40.697617                     38.348794
# 13                     15.941555                      5.223020
# 14                      5.640647                      9.850233
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       5.942409          1.335490e+12
# 1                     -23.698738          3.127347e+11
# 2                      -0.000868          1.199646e+11
# 3                       4.348188          8.650469e+10
# 4                      -1.494604          7.269288e+10
# 5                       0.025882          3.477529e+10
# 6                      -3.605842          3.107039e+10
# 7                       5.794065          1.845462e+10
# 8                      19.163284          1.380103e+10
# 9                     -27.260626          1.327688e+10
# 10                    -17.603331          1.232413e+10
# 11                      1.531162          1.114662e+10
# 12                      6.860117          1.089896e+10
# 13                     -3.476434          7.176955e+09
# 14                    -17.978736          6.976710e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          57.6062                        1.418688e+12
# 1                          13.4898                        3.127347e+11
# 2                           5.1791                        1.213553e+11
# 3                           3.7314                        8.650469e+10
# 4                           3.1383                        9.077248e+10
# 5                           1.5000                        3.477529e+10
# 6                           1.3414                        5.485102e+10
# 7                           0.7967                        1.845462e+10
# 8                           0.5958                        1.380104e+10
# 9                           0.5727                        2.673656e+10
# 10                          0.5321                        1.586018e+10
# 11                          0.4808                        1.962087e+10
# 12                          0.4701                        1.090361e+10
# 13                          0.3096                        7.621522e+09
# 14                          0.3009                        1.112979e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 1           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 2           None  2024-10-16T16:34:00.000Z       1027.0      Ethereum
# 3           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 4           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 5           None  2024-10-16T16:34:00.000Z       1027.0      Ethereum
# 6           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 7           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 8           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 9           None  2024-10-16T16:34:00.000Z          NaN           NaN
# 10          None  2024-10-16T16:34:00.000Z          NaN           NaN
# 11          None  2024-10-16T16:34:00.000Z          NaN           NaN
# 12          None  2024-10-16T16:34:00.000Z       1027.0      Ethereum
# 13          None  2024-10-16T16:34:00.000Z          NaN           NaN
# 14          None  2024-10-16T16:34:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
#
#                     timestamp
# 0  2024-10-16 17:39:02.479842
# 1  2024-10-16 17:39:02.479842
# 2  2024-10-16 17:39:02.479842
# 3  2024-10-16 17:39:02.479842
# 4  2024-10-16 17:39:02.479842
# 5  2024-10-16 17:39:02.479842
# 6  2024-10-16 17:39:02.479842
# 7  2024-10-16 17:39:02.479842
# 8  2024-10-16 17:39:02.479842
# 9  2024-10-16 17:39:02.479842
# 10 2024-10-16 17:39:02.479842
# 11 2024-10-16 17:39:02.479842
# 12 2024-10-16 17:39:02.479842
# 13 2024-10-16 17:39:02.479842
# 14 2024-10-16 17:39:02.479842

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'

# %%
 parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
headers = {
      'Accepts':'application/json',
      'X-CMC_PRO_API_KEY':'0ad53085-1cb2-4eb8-ad9e-3ffbd7e5650'
   }
session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
except(ConnectionError, Timeout, TooManyDirects) as e:
    print(e)

# %%
df2 = pd.json_normalize(data)
df2['Timestamp'] = pd.to_datetime('now')
df_append = pd.DataFrame(df2)
df = pd.concat([df2,df_append])

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed

# %%
df72 = pd.read_csv(r'C:\Users\subomi\Documents\Python Scripts\API.csv')
df72

# %%
df

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3

# %%
df4 = df3.stack()
df4

# %%
df5 = df4.to_frame(name='values')
df5

# %%
df5.count()

# %%
index = pd.Index(range(90))


df6 = df5.set_index(index)
df6

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
